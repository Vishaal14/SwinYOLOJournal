# %%
# !pip uninstall -y timm
# !pip install -U timm
# Out:
# Found existing installation: timm 1.0.24
# Uninstalling timm-1.0.24:
#   Successfully uninstalled timm-1.0.24
# Collecting timm
#   Using cached timm-1.0.24-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.24.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.20.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2026.1.4)
# Using cached timm-1.0.24-py3-none-any.whl (2.6 MB)
# Installing collected packages: timm
# Successfully installed timm-1.0.24

# %%
import timm
print("timm version:", timm.__version__)

print("\nAvailable Swin models:")
for m in timm.list_models("*swin*"):
    print(m)
# Out:
# timm version: 1.0.24
#
# Available Swin models:
# hiera_base_abswin_256
# hiera_small_abswin_256
# swin_base_patch4_window7_224
# swin_base_patch4_window12_384
# swin_large_patch4_window7_224
# swin_large_patch4_window12_384
# swin_s3_base_224
# swin_s3_small_224
# swin_s3_tiny_224
# swin_small_patch4_window7_224
# swin_tiny_patch4_window7_224
# swinv2_base_window8_256
# swinv2_base_window12_192
# swinv2_base_window12to16_192to256
# swinv2_base_window12to24_192to384
# swinv2_base_window16_256
# swinv2_cr_base_224
# swinv2_cr_base_384
# swinv2_cr_base_ns_224
# swinv2_cr_giant_224
# swinv2_cr_giant_384
# swinv2_cr_huge_224
# swinv2_cr_huge_384
# swinv2_cr_large_224
# swinv2_cr_large_384
# swinv2_cr_small_224
# swinv2_cr_small_384
# swinv2_cr_small_ns_224
# swinv2_cr_small_ns_256
# swinv2_cr_tiny_224
# swinv2_cr_tiny_384
# swinv2_cr_tiny_ns_224
# swinv2_large_window12_192
# swinv2_large_window12to16_192to256
# swinv2_large_window12to24_192to384
# swinv2_small_window8_256
# swinv2_small_window16_256
# swinv2_tiny_window8_256
# swinv2_tiny_window16_256

# %%
# !rm -rf /content/yolov5/Pascal-Voc-2007-1

# %%
import torch, sys, os
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.9.0+cu126
# CUDA available: True

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.1.46)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.16.3)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (0.24.0+cu126)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (8.4.5)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 42)) (25.0)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 43)) (75.2.0)
# Requirement already satisfied: urllib3>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 51)) (2.6.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.5.0)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (2.0.18)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.3)

# %%
# Download YOLOv5 small pretrained weights
# !wget https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# Out:
# --2026-01-18 17:20:16--  https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/264818686/381bd8a8-8910-4e9e-b0dd-2752951ef78c?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-18T18%3A14%3A53Z&rscd=attachment%3B+filename%3Dyolov5s.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-18T17%3A14%3A24Z&ske=2026-01-18T18%3A14%3A53Z&sks=b&skv=2018-11-09&sig=Wp0dZyoZprvyulwyjnA1hiCUfxmla%2BdJJuWwioBaKlg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2ODc1ODUyNywibmJmIjoxNzY4NzU2NzI3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.SFYzud2GvE0t4SCGcCS8fiXfs9mw3MAusy6eefAmx20&response-content-disposition=attachment%3B%20filename%3Dyolov5s.pt&response-content-type=application%2Foctet-stream [following]
# --2026-01-18 17:20:16--  https://release-assets.githubusercontent.com/github-production-release-asset/264818686/381bd8a8-8910-4e9e-b0dd-2752951ef78c?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-18T18%3A14%3A53Z&rscd=attachment%3B+filename%3Dyolov5s.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-18T17%3A14%3A24Z&ske=2026-01-18T18%3A14%3A53Z&sks=b&skv=2018-11-09&sig=Wp0dZyoZprvyulwyjnA1hiCUfxmla%2BdJJuWwioBaKlg%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2ODc1ODUyNywibmJmIjoxNzY4NzU2NzI3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.SFYzud2GvE0t4SCGcCS8fiXfs9mw3MAusy6eefAmx20&response-content-disposition=attachment%3B%20filename%3Dyolov5s.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14808437 (14M) [application/octet-stream]
# Saving to: ‘yolov5s.pt.2’
#
# yolov5s.pt.2        100%[===================>]  14.12M  --.-KB/s    in 0.04s
#
# 2026-01-18 17:20:16 (319 MB/s) - ‘yolov5s.pt.2’ saved [14808437/14808437]

# %%
import os
assert os.path.exists("yolov5s.pt"), "❌ yolov5s.pt not found!"
print("✅ yolov5s.pt found")
# Out:
# ✅ yolov5s.pt found

# %%
# !pip install roboflow
from roboflow import Roboflow

rf = Roboflow(api_key="GYiLvqoCXhBZ3NWSGyrR")
project = rf.workspace("modd2").project("pascal-voc-2007-bhjgf")
dataset = project.version(1).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.1.4)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Pascal-Voc-2007-1 to yolov5pytorch:: 100%|██████████| 308572/308572 [00:17<00:00, 17821.60it/s]
# Extracting Dataset Version Zip to Pascal-Voc-2007-1 in yolov5pytorch:: 100%|██████████| 10026/10026 [00:01<00:00, 6744.22it/s]

# %%
import yaml
from pathlib import Path

data_yaml = Path("/content/yolov5/Pascal-Voc-2007-1/data.yaml")

with open(data_yaml) as f:
    data = yaml.safe_load(f)

root = "/content/Pascal-Voc-2007-1"
data["train"] = f"{root}/train/images"
data["val"]   = f"{root}/valid/images"
data["test"]  = f"{root}/test/images"

with open(data_yaml, "w") as f:
    yaml.safe_dump(data, f)

print("✅ Dataset paths fixed")
# Out:
# ✅ Dataset paths fixed

# %%
# swin_yolov5_pascal2007_base.py
# ------------------------------------------------------------
# Swin backbone + YOLOv5 pretrained Detect head (Option A)
# ------------------------------------------------------------

import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import timm
from models.yolo import Detect


# ------------------------------------------------------------
# SWIN BACKBONE
# ------------------------------------------------------------
class SwinBackbone(nn.Module):
    def __init__(self, variant="swinv2_tiny_window8_256"):
        super().__init__()

        self.swin = timm.create_model(
            variant,
            pretrained=True,
            features_only=True,
            out_indices=(1, 2, 3),
        )

        # SwinV2 channels → YOLO channels
        self.cv3 = nn.Conv2d(192, 256, 1)
        self.cv4 = nn.Conv2d(384, 512, 1)
        self.cv5 = nn.Conv2d(768, 1024, 1)

        self.required_multiple = 8 * 16  # window8 × downsample16

    def forward(self, x):
        B, C, H, W = x.shape
        m = self.required_multiple

        pad_h = (math.ceil(H / m) * m) - H
        pad_w = (math.ceil(W / m) * m) - W
        if pad_h or pad_w:
            x = F.pad(x, (0, pad_w, 0, pad_h))

        f = self.swin(x)

        p3 = self.cv3(f[0].permute(0, 3, 1, 2))
        p4 = self.cv4(f[1].permute(0, 3, 1, 2))
        p5 = self.cv5(f[2].permute(0, 3, 1, 2))

        return [p3, p4, p5]


# ------------------------------------------------------------
# SWIN + YOLOv5 DETECT
# ------------------------------------------------------------
class SwinYOLO(nn.Module):
    def __init__(self, nc=20, anchors=None):
        super().__init__()

        self.backbone = SwinBackbone()

        self.detect = Detect(
            nc=nc,
            anchors=anchors,
            ch=[256, 512, 1024],
        )

        # REQUIRED: initialize stride/grid
        self.detect.stride = torch.tensor([8., 16., 32.])

        # --------------------------------------------------
        # ✅ YOLOv5-COMPATIBILITY ATTRIBUTES (CRITICAL)
        # --------------------------------------------------
        self.model = nn.ModuleList([self.backbone, self.detect])
        self.nc = nc
        self.names = [str(i) for i in range(nc)]

    def forward(self, x, augment=False):
      feats = self.backbone(x)
      return self.detect(feats)







# ------------------------------------------------------------
# LOAD PRETRAINED YOLOv5 DETECT WEIGHTS
# ------------------------------------------------------------
def load_yolov5_detect(model, weights="yolov5s.pt"):
    ckpt = torch.load(weights, map_location="cpu", weights_only=False)
    state = ckpt["model"].float().state_dict()

    detect_state = {}
    for k, v in state.items():
        if k.startswith("model.24."):
            new_k = k.replace("model.24.", "")
            if new_k in model.detect.state_dict() and \
               v.shape == model.detect.state_dict()[new_k].shape:
                detect_state[new_k] = v

    model.detect.load_state_dict(detect_state, strict=False)
    print(f"✅ Loaded {len(detect_state)} pretrained Detect layers")


# ------------------------------------------------------------
# SANITY CHECK
# ------------------------------------------------------------
if __name__ == "__main__":
    anchors = [
        [10,13, 16,30, 33,23],
        [30,61, 62,45, 59,119],
        [116,90, 156,198, 373,326],
    ]

    model = SwinYOLO(nc=20, anchors=anchors)
    load_yolov5_detect(model)

    x = torch.zeros(1, 3, 256, 256)
    y = model(x)

    print("✅ Forward pass successful")
# Out:
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# ✅ Loaded 1 pretrained Detect layers
# ✅ Forward pass successful

# %%
print("Detect nc:", model.detect.nc)
print("Detect anchors:", model.detect.anchors)
print("Detect stride:", model.detect.stride)
for i, m in enumerate(model.detect.m):
    print(f"Detect scale {i} input channels:", m.weight.shape[1])
# Out:
# Detect nc: 20
# Detect anchors: tensor([[[ 1.25000,  1.62500],
#          [ 2.00000,  3.75000],
#          [ 4.12500,  2.87500]],
#
#         [[ 1.87500,  3.81250],
#          [ 3.87500,  2.81250],
#          [ 3.68750,  7.43750]],
#
#         [[ 3.62500,  2.81250],
#          [ 4.87500,  6.18750],
#          [11.65625, 10.18750]]])
# Detect stride: tensor([ 8., 16., 32.])
# Detect scale 0 input channels: 256
# Detect scale 1 input channels: 512
# Detect scale 2 input channels: 1024

# %%
x = torch.zeros(1, 3, 256, 256)
y = model(x)

for i, out in enumerate(y):
    print(f"Scale {i} output shape:", out.shape)
# Out:
# Scale 0 output shape: torch.Size([1, 3, 32, 32, 25])
# Scale 1 output shape: torch.Size([1, 3, 16, 16, 25])
# Scale 2 output shape: torch.Size([1, 3, 8, 8, 25])

# %%
x = torch.randn(2, 3, 256, 256)
y = model(x)

loss = sum(o.sum() for o in y)
loss.backward()

print("✅ Backward pass successful")
# Out:
# ✅ Backward pass successful

# %%
# !python swin_yolov5_pascal2007_base.py
# Out:
# ✅ Loaded 1 pretrained Detect layers
# ✅ Forward pass successful

# %%
# !python -c "import timm; print(timm.__version__)"
# Out:
# 1.0.24

# %%
# train_swin_yolo.py
# train_swin_yolo.py
import torch
import yaml
from pathlib import Path
from tqdm import tqdm
import sys
from copy import deepcopy

# ------------------------------------------------------------
# PATHS
# ------------------------------------------------------------
YOLO_ROOT = Path("/content/yolov5")
DATA_YAML = "/content/yolov5/Pascal-Voc-2007-1/data.yaml"
HYP_YAML = "/content/yolov5/data/hyps/hyp.scratch-low.yaml"

sys.path.append(str(YOLO_ROOT))

# ------------------------------------------------------------
# YOLOv5 IMPORTS
# ------------------------------------------------------------
from utils.dataloaders import create_dataloader
from utils.loss import ComputeLoss
from val import run as val_run
from utils.torch_utils import select_device

# ------------------------------------------------------------
# OUR MODEL
# ------------------------------------------------------------
from swin_yolov5_pascal2007_base import SwinYOLO, load_yolov5_detect

# ------------------------------------------------------------
# TRAINING CONFIG
# ------------------------------------------------------------
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 40

LR = 2e-4
FREEZE_EPOCHS = 5

DEVICE = select_device("0" if torch.cuda.is_available() else "cpu")

# ------------------------------------------------------------
# LOAD DATA + HYP
# ------------------------------------------------------------
with open(DATA_YAML) as f:
    data = yaml.safe_load(f)

with open(HYP_YAML) as f:
    hyp = yaml.safe_load(f)

nc = int(data["nc"])

# ------------------------------------------------------------
# BUILD MODEL
# ------------------------------------------------------------
anchors = [
    [10, 13, 16, 30, 33, 23],
    [30, 61, 62, 45, 59, 119],
    [116, 90, 156, 198, 373, 326],
]

model = SwinYOLO(nc=nc, anchors=anchors).to(DEVICE)
load_yolov5_detect(model)

# REQUIRED by ComputeLoss
model.hyp = hyp
model.train()

# ------------------------------------------------------------
# FREEZE BACKBONE (WARMUP)
# ------------------------------------------------------------
for p in model.backbone.parameters():
    p.requires_grad = False

print(f"🔒 Swin backbone frozen for first {FREEZE_EPOCHS} epochs")

# ------------------------------------------------------------
# DATALOADERS
# ------------------------------------------------------------
train_loader, _ = create_dataloader(
    path=data["train"],
    imgsz=IMG_SIZE,
    batch_size=BATCH_SIZE,
    stride=32,
    single_cls=False,
    hyp=hyp,
    augment=True,
    cache=False,
    rect=False,
    rank=-1,
    workers=4,
)

val_loader, _ = create_dataloader(
    path=data["val"],
    imgsz=IMG_SIZE,
    batch_size=BATCH_SIZE,
    stride=32,
    single_cls=False,
    hyp=hyp,
    augment=False,
    cache=False,
    rect=True,
    rank=-1,
    workers=4,
)

# ------------------------------------------------------------
# LOSS + OPTIMIZER
# ------------------------------------------------------------
compute_loss = ComputeLoss(model)

optimizer = torch.optim.SGD(
    model.parameters(),
    lr=LR,
    momentum=0.9,
    weight_decay=5e-4
)

# ------------------------------------------------------------
# TRAIN LOOP
# ------------------------------------------------------------
for epoch in range(EPOCHS):

    # 🔓 Unfreeze backbone automatically
    if epoch == FREEZE_EPOCHS:
        print("🔓 Unfreezing Swin backbone")
        for p in model.backbone.parameters():
            p.requires_grad = True

    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}")
    mloss = torch.zeros(3, device=DEVICE)

    # -------------------- TRAIN --------------------
    for imgs, targets, paths, _ in pbar:
        imgs = imgs.to(DEVICE).float() / 255.0
        targets = targets.to(DEVICE)

        preds = model(imgs)
        loss, loss_items = compute_loss(preds, targets)

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 10.0)
        optimizer.step()

        mloss = mloss * 0.9 + loss_items * 0.1

        pbar.set_postfix(
            box=f"{mloss[0]:.3f}",
            obj=f"{mloss[1]:.3f}",
            cls=f"{mloss[2]:.3f}",
            total=f"{loss.item():.3f}",
        )

    print(f"Epoch {epoch+1}/{EPOCHS} | loss: {loss.item():.4f}")

    # --------------------------------------------------------
    # VALIDATION (SAFE, AUTOGRAD-PROOF)
    # --------------------------------------------------------
    model.eval()

    with torch.no_grad():
        eval_model = deepcopy(model).to(DEVICE)

        results, maps, _ = val_run(
            data=data,
            model=eval_model,
            dataloader=val_loader,
            imgsz=IMG_SIZE,
            conf_thres=0.001,
            iou_thres=0.6,
            device=DEVICE,
            single_cls=False,
            save_json=False,
            verbose=False,
        )

    del eval_model
    torch.cuda.empty_cache()

    model.train()
    torch.set_grad_enabled(True)

    P, R, mAP50, mAP5095 = results[:4]
    print(
        f"📊 Val | "
        f"P: {P:.4f} | "
        f"R: {R:.4f} | "
        f"mAP@0.5: {mAP50:.4f} | "
        f"mAP@0.5:0.95: {mAP5095:.4f}"
    )

print("\n✅ Training complete")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4117724056.py in <cell line: 0>()
#      26 sys.path.append(str(YOLO_ROOT))
#      27
# ---> 28 from yolov5.utils.datasets import create_dataloader
#      29 from yolov5.utils.loss import ComputeLoss
#      30 from yolov5.utils.general import check_img_size
#
# ModuleNotFoundError: No module named 'yolov5.utils.datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !python train_swin_yolo.py
# Out:
# YOLOv5 🚀 v7.0-457-g84ef1e59 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# ✅ Loaded 1 pretrained Detect layers
# 🔒 Swin backbone frozen for first 5 epochs
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# Scanning /content/yolov5/Pascal-Voc-2007-1/train/labels.cache... 3506 images, 32 backgrounds, 0 corrupt: 100% 3506/3506 [00:00<?, ?it/s]
# Scanning /content/yolov5/Pascal-Voc-2007-1/valid/labels.cache... 1001 images, 6 backgrounds, 0 corrupt: 100% 1001/1001 [00:00<?, ?it/s]
# Epoch 1/40: 100% 439/439 [00:50<00:00,  8.61it/s, box=0.105, cls=0.602, obj=0.221, total=1.967]
# Epoch 1/40 | loss: 1.9667
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [01:02<00:00,  2.03it/s]
#                    all       1001       3021    0.00389     0.0446    0.00171   0.000497
# 📊 Val | P: 0.0039 | R: 0.0446 | mAP@0.5: 0.0017 | mAP@0.5:0.95: 0.0005
# Epoch 2/40: 100% 439/439 [00:49<00:00,  8.92it/s, box=0.103, cls=0.476, obj=0.202, total=1.653]
# Epoch 2/40 | loss: 1.6529
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:58<00:00,  2.17it/s]
#                    all       1001       3021    0.00386     0.0507    0.00186   0.000517
# 📊 Val | P: 0.0039 | R: 0.0507 | mAP@0.5: 0.0019 | mAP@0.5:0.95: 0.0005
# Epoch 3/40: 100% 439/439 [00:48<00:00,  9.02it/s, box=0.101, cls=0.417, obj=0.202, total=1.476]
# Epoch 3/40 | loss: 1.4764
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:51<00:00,  2.46it/s]
#                    all       1001       3021    0.00501     0.0533    0.00246   0.000659
# 📊 Val | P: 0.0050 | R: 0.0533 | mAP@0.5: 0.0025 | mAP@0.5:0.95: 0.0007
# Epoch 4/40: 100% 439/439 [00:49<00:00,  8.93it/s, box=0.094, cls=0.356, obj=0.200, total=0.714]
# Epoch 4/40 | loss: 0.7138
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:42<00:00,  2.95it/s]
#                    all       1001       3021    0.00636     0.0498    0.00326   0.000826
# 📊 Val | P: 0.0064 | R: 0.0498 | mAP@0.5: 0.0033 | mAP@0.5:0.95: 0.0008
# Epoch 5/40: 100% 439/439 [00:47<00:00,  9.19it/s, box=0.097, cls=0.352, obj=0.188, total=1.074]
# Epoch 5/40 | loss: 1.0741
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:36<00:00,  3.44it/s]
#                    all       1001       3021    0.00714     0.0454    0.00375   0.000992
# 📊 Val | P: 0.0071 | R: 0.0454 | mAP@0.5: 0.0038 | mAP@0.5:0.95: 0.0010
# 🔓 Unfreezing Swin backbone
# Epoch 6/40: 100% 439/439 [01:23<00:00,  5.25it/s, box=0.094, cls=0.235, obj=0.188, total=1.010]
# Epoch 6/40 | loss: 1.0097
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.81it/s]
#                    all       1001       3021     0.0531     0.0723     0.0313    0.00679
# 📊 Val | P: 0.0531 | R: 0.0723 | mAP@0.5: 0.0313 | mAP@0.5:0.95: 0.0068
# Epoch 7/40: 100% 439/439 [01:25<00:00,  5.14it/s, box=0.092, cls=0.223, obj=0.174, total=0.937]
# Epoch 7/40 | loss: 0.9371
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.76it/s]
#                    all       1001       3021      0.139      0.151     0.0581     0.0128
# 📊 Val | P: 0.1390 | R: 0.1509 | mAP@0.5: 0.0581 | mAP@0.5:0.95: 0.0128
# Epoch 8/40: 100% 439/439 [01:25<00:00,  5.15it/s, box=0.092, cls=0.212, obj=0.183, total=0.944]
# Epoch 8/40 | loss: 0.9443
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.64it/s]
#                    all       1001       3021      0.165      0.196     0.0732      0.017
# 📊 Val | P: 0.1654 | R: 0.1960 | mAP@0.5: 0.0732 | mAP@0.5:0.95: 0.0170
# Epoch 9/40: 100% 439/439 [01:26<00:00,  5.10it/s, box=0.090, cls=0.199, obj=0.198, total=1.075]
# Epoch 9/40 | loss: 1.0755
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.12it/s]
#                    all       1001       3021      0.239      0.204     0.0853     0.0197
# 📊 Val | P: 0.2393 | R: 0.2037 | mAP@0.5: 0.0853 | mAP@0.5:0.95: 0.0197
# Epoch 10/40: 100% 439/439 [01:25<00:00,  5.12it/s, box=0.089, cls=0.192, obj=0.186, total=0.853]
# Epoch 10/40 | loss: 0.8533
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.45it/s]
#                    all       1001       3021      0.181      0.223      0.107     0.0248
# 📊 Val | P: 0.1808 | R: 0.2234 | mAP@0.5: 0.1074 | mAP@0.5:0.95: 0.0248
# Epoch 11/40: 100% 439/439 [01:25<00:00,  5.14it/s, box=0.083, cls=0.175, obj=0.170, total=0.422]
# Epoch 11/40 | loss: 0.4223
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.99it/s]
#                    all       1001       3021      0.197       0.25      0.125     0.0302
# 📊 Val | P: 0.1966 | R: 0.2504 | mAP@0.5: 0.1249 | mAP@0.5:0.95: 0.0302
# Epoch 12/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.087, cls=0.190, obj=0.193, total=1.034]
# Epoch 12/40 | loss: 1.0335
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.09it/s]
#                    all       1001       3021       0.23      0.274      0.141     0.0344
# 📊 Val | P: 0.2296 | R: 0.2740 | mAP@0.5: 0.1409 | mAP@0.5:0.95: 0.0344
# Epoch 13/40: 100% 439/439 [01:25<00:00,  5.14it/s, box=0.085, cls=0.186, obj=0.191, total=1.251]
# Epoch 13/40 | loss: 1.2511
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.32it/s]
#                    all       1001       3021      0.211      0.255      0.117     0.0275
# 📊 Val | P: 0.2106 | R: 0.2553 | mAP@0.5: 0.1167 | mAP@0.5:0.95: 0.0275
# Epoch 14/40: 100% 439/439 [01:26<00:00,  5.05it/s, box=0.087, cls=0.167, obj=0.200, total=0.936]
# Epoch 14/40 | loss: 0.9356
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.39it/s]
#                    all       1001       3021      0.216      0.291       0.15     0.0368
# 📊 Val | P: 0.2159 | R: 0.2913 | mAP@0.5: 0.1495 | mAP@0.5:0.95: 0.0368
# Epoch 15/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.080, cls=0.155, obj=0.171, total=0.321]
# Epoch 15/40 | loss: 0.3208
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.00it/s]
#                    all       1001       3021      0.244      0.287      0.173     0.0439
# 📊 Val | P: 0.2444 | R: 0.2866 | mAP@0.5: 0.1730 | mAP@0.5:0.95: 0.0439
# Epoch 16/40: 100% 439/439 [01:26<00:00,  5.10it/s, box=0.084, cls=0.174, obj=0.183, total=0.841]
# Epoch 16/40 | loss: 0.8411
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.33it/s]
#                    all       1001       3021      0.248      0.312      0.191     0.0529
# 📊 Val | P: 0.2485 | R: 0.3118 | mAP@0.5: 0.1909 | mAP@0.5:0.95: 0.0529
# Epoch 17/40: 100% 439/439 [01:25<00:00,  5.13it/s, box=0.085, cls=0.164, obj=0.188, total=0.792]
# Epoch 17/40 | loss: 0.7918
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.06it/s]
#                    all       1001       3021      0.263      0.305      0.193     0.0532
# 📊 Val | P: 0.2628 | R: 0.3047 | mAP@0.5: 0.1929 | mAP@0.5:0.95: 0.0532
# Epoch 18/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.083, cls=0.152, obj=0.172, total=0.802]
# Epoch 18/40 | loss: 0.8020
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.30it/s]
#                    all       1001       3021      0.288      0.315        0.2     0.0547
# 📊 Val | P: 0.2881 | R: 0.3150 | mAP@0.5: 0.2005 | mAP@0.5:0.95: 0.0547
# Epoch 19/40: 100% 439/439 [01:23<00:00,  5.23it/s, box=0.082, cls=0.172, obj=0.191, total=0.991]
# Epoch 19/40 | loss: 0.9909
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.23it/s]
#                    all       1001       3021      0.278      0.326      0.218     0.0598
# 📊 Val | P: 0.2778 | R: 0.3265 | mAP@0.5: 0.2180 | mAP@0.5:0.95: 0.0598
# Epoch 20/40: 100% 439/439 [01:23<00:00,  5.23it/s, box=0.082, cls=0.156, obj=0.187, total=0.556]
# Epoch 20/40 | loss: 0.5559
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.11it/s]
#                    all       1001       3021      0.329      0.329      0.235     0.0672
# 📊 Val | P: 0.3288 | R: 0.3286 | mAP@0.5: 0.2351 | mAP@0.5:0.95: 0.0672
# Epoch 21/40: 100% 439/439 [01:24<00:00,  5.20it/s, box=0.084, cls=0.158, obj=0.196, total=1.012]
# Epoch 21/40 | loss: 1.0119
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.16it/s]
#                    all       1001       3021      0.324      0.314      0.231     0.0642
# 📊 Val | P: 0.3241 | R: 0.3143 | mAP@0.5: 0.2307 | mAP@0.5:0.95: 0.0642
# Epoch 22/40: 100% 439/439 [01:24<00:00,  5.18it/s, box=0.082, cls=0.154, obj=0.190, total=0.834]
# Epoch 22/40 | loss: 0.8336
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.85it/s]
#                    all       1001       3021      0.325      0.317      0.225     0.0642
# 📊 Val | P: 0.3253 | R: 0.3174 | mAP@0.5: 0.2252 | mAP@0.5:0.95: 0.0642
# Epoch 23/40: 100% 439/439 [01:23<00:00,  5.25it/s, box=0.082, cls=0.165, obj=0.172, total=1.001]
# Epoch 23/40 | loss: 1.0011
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.11it/s]
#                    all       1001       3021       0.35       0.33      0.236     0.0703
# 📊 Val | P: 0.3504 | R: 0.3304 | mAP@0.5: 0.2362 | mAP@0.5:0.95: 0.0703
# Epoch 24/40: 100% 439/439 [01:24<00:00,  5.21it/s, box=0.081, cls=0.148, obj=0.176, total=0.554]
# Epoch 24/40 | loss: 0.5540
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.99it/s]
#                    all       1001       3021      0.315      0.338      0.238     0.0707
# 📊 Val | P: 0.3148 | R: 0.3377 | mAP@0.5: 0.2380 | mAP@0.5:0.95: 0.0707
# Epoch 25/40: 100% 439/439 [01:25<00:00,  5.15it/s, box=0.082, cls=0.150, obj=0.184, total=0.776]
# Epoch 25/40 | loss: 0.7758
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.73it/s]
#                    all       1001       3021      0.313      0.338      0.237     0.0672
# 📊 Val | P: 0.3130 | R: 0.3383 | mAP@0.5: 0.2373 | mAP@0.5:0.95: 0.0672
# Epoch 26/40: 100% 439/439 [01:27<00:00,  5.01it/s, box=0.082, cls=0.153, obj=0.182, total=0.840]
# Epoch 26/40 | loss: 0.8396
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.39it/s]
#                    all       1001       3021      0.354      0.343      0.269     0.0795
# 📊 Val | P: 0.3542 | R: 0.3429 | mAP@0.5: 0.2689 | mAP@0.5:0.95: 0.0795
# Epoch 27/40: 100% 439/439 [01:27<00:00,  5.04it/s, box=0.080, cls=0.155, obj=0.171, total=0.986]
# Epoch 27/40 | loss: 0.9863
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.91it/s]
#                    all       1001       3021      0.366      0.352      0.274      0.081
# 📊 Val | P: 0.3656 | R: 0.3518 | mAP@0.5: 0.2744 | mAP@0.5:0.95: 0.0810
# Epoch 28/40: 100% 439/439 [01:27<00:00,  5.02it/s, box=0.077, cls=0.145, obj=0.181, total=0.405]
# Epoch 28/40 | loss: 0.4050
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.62it/s]
#                    all       1001       3021      0.359      0.351      0.285      0.087
# 📊 Val | P: 0.3592 | R: 0.3512 | mAP@0.5: 0.2847 | mAP@0.5:0.95: 0.0870
# Epoch 29/40: 100% 439/439 [01:28<00:00,  4.98it/s, box=0.081, cls=0.141, obj=0.190, total=0.835]
# Epoch 29/40 | loss: 0.8346
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.34it/s]
#                    all       1001       3021      0.383      0.356      0.292      0.091
# 📊 Val | P: 0.3834 | R: 0.3557 | mAP@0.5: 0.2922 | mAP@0.5:0.95: 0.0910
# Epoch 30/40: 100% 439/439 [01:24<00:00,  5.18it/s, box=0.079, cls=0.151, obj=0.191, total=0.824]
# Epoch 30/40 | loss: 0.8239
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.67it/s]
#                    all       1001       3021      0.379      0.361      0.295     0.0911
# 📊 Val | P: 0.3790 | R: 0.3610 | mAP@0.5: 0.2955 | mAP@0.5:0.95: 0.0911
# Epoch 31/40: 100% 439/439 [01:24<00:00,  5.21it/s, box=0.080, cls=0.142, obj=0.174, total=0.765]
# Epoch 31/40 | loss: 0.7647
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.26it/s]
#                    all       1001       3021      0.365      0.343      0.283     0.0859
# 📊 Val | P: 0.3655 | R: 0.3426 | mAP@0.5: 0.2833 | mAP@0.5:0.95: 0.0859
# Epoch 32/40: 100% 439/439 [01:25<00:00,  5.15it/s, box=0.079, cls=0.147, obj=0.174, total=0.671]
# Epoch 32/40 | loss: 0.6707
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.12it/s]
#                    all       1001       3021      0.402      0.357      0.311     0.0955
# 📊 Val | P: 0.4018 | R: 0.3567 | mAP@0.5: 0.3107 | mAP@0.5:0.95: 0.0955
# Epoch 33/40: 100% 439/439 [01:25<00:00,  5.12it/s, box=0.081, cls=0.147, obj=0.189, total=0.880]
# Epoch 33/40 | loss: 0.8797
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.49it/s]
#                    all       1001       3021      0.372      0.335      0.275     0.0775
# 📊 Val | P: 0.3722 | R: 0.3349 | mAP@0.5: 0.2748 | mAP@0.5:0.95: 0.0775
# Epoch 34/40: 100% 439/439 [01:26<00:00,  5.10it/s, box=0.076, cls=0.133, obj=0.181, total=0.489]
# Epoch 34/40 | loss: 0.4890
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.58it/s]
#                    all       1001       3021      0.402      0.359       0.32      0.105
# 📊 Val | P: 0.4024 | R: 0.3591 | mAP@0.5: 0.3196 | mAP@0.5:0.95: 0.1047
# Epoch 35/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.079, cls=0.142, obj=0.191, total=0.854]
# Epoch 35/40 | loss: 0.8541
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.33it/s]
#                    all       1001       3021      0.414       0.36      0.317      0.105
# 📊 Val | P: 0.4137 | R: 0.3604 | mAP@0.5: 0.3172 | mAP@0.5:0.95: 0.1047
# Epoch 36/40: 100% 439/439 [01:24<00:00,  5.18it/s, box=0.080, cls=0.142, obj=0.172, total=0.753]
# Epoch 36/40 | loss: 0.7528
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.56it/s]
#                    all       1001       3021      0.394      0.364      0.315     0.0937
# 📊 Val | P: 0.3936 | R: 0.3643 | mAP@0.5: 0.3148 | mAP@0.5:0.95: 0.0937
# Epoch 37/40: 100% 439/439 [01:25<00:00,  5.13it/s, box=0.077, cls=0.140, obj=0.173, total=0.519]
# Epoch 37/40 | loss: 0.5194
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.48it/s]
#                    all       1001       3021      0.422      0.373      0.333      0.114
# 📊 Val | P: 0.4223 | R: 0.3726 | mAP@0.5: 0.3330 | mAP@0.5:0.95: 0.1135
# Epoch 38/40: 100% 439/439 [01:25<00:00,  5.14it/s, box=0.079, cls=0.143, obj=0.195, total=0.901]
# Epoch 38/40 | loss: 0.9005
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.55it/s]
#                    all       1001       3021       0.42       0.38      0.329      0.107
# 📊 Val | P: 0.4196 | R: 0.3801 | mAP@0.5: 0.3291 | mAP@0.5:0.95: 0.1066
# Epoch 39/40: 100% 439/439 [01:26<00:00,  5.08it/s, box=0.079, cls=0.137, obj=0.183, total=0.803]
# Epoch 39/40 | loss: 0.8033
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.66it/s]
#                    all       1001       3021      0.423      0.362      0.336      0.107
# 📊 Val | P: 0.4225 | R: 0.3619 | mAP@0.5: 0.3357 | mAP@0.5:0.95: 0.1067
# Epoch 40/40: 100% 439/439 [01:25<00:00,  5.12it/s, box=0.079, cls=0.135, obj=0.186, total=0.602]
# Epoch 40/40 | loss: 0.6017
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.67it/s]
#                    all       1001       3021       0.42      0.376      0.339      0.107
# 📊 Val | P: 0.4202 | R: 0.3760 | mAP@0.5: 0.3386 | mAP@0.5:0.95: 0.1069
#
# ✅ Training complete
