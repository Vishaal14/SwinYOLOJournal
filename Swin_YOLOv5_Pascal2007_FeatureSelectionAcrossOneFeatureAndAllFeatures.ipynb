# %%
# !pip uninstall -y timm
# !pip install -U timm
# Out:
# Found existing installation: timm 1.0.24
# Uninstalling timm-1.0.24:
#   Successfully uninstalled timm-1.0.24
# Collecting timm
#   Using cached timm-1.0.24-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.24.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2026.1.4)
# Using cached timm-1.0.24-py3-none-any.whl (2.6 MB)
# Installing collected packages: timm
# Successfully installed timm-1.0.24

# %%
import timm
print("timm version:", timm.__version__)

print("\nAvailable Swin models:")
for m in timm.list_models("*swin*"):
    print(m)
# Out:
# timm version: 1.0.24
#
# Available Swin models:
# hiera_base_abswin_256
# hiera_small_abswin_256
# swin_base_patch4_window7_224
# swin_base_patch4_window12_384
# swin_large_patch4_window7_224
# swin_large_patch4_window12_384
# swin_s3_base_224
# swin_s3_small_224
# swin_s3_tiny_224
# swin_small_patch4_window7_224
# swin_tiny_patch4_window7_224
# swinv2_base_window8_256
# swinv2_base_window12_192
# swinv2_base_window12to16_192to256
# swinv2_base_window12to24_192to384
# swinv2_base_window16_256
# swinv2_cr_base_224
# swinv2_cr_base_384
# swinv2_cr_base_ns_224
# swinv2_cr_giant_224
# swinv2_cr_giant_384
# swinv2_cr_huge_224
# swinv2_cr_huge_384
# swinv2_cr_large_224
# swinv2_cr_large_384
# swinv2_cr_small_224
# swinv2_cr_small_384
# swinv2_cr_small_ns_224
# swinv2_cr_small_ns_256
# swinv2_cr_tiny_224
# swinv2_cr_tiny_384
# swinv2_cr_tiny_ns_224
# swinv2_large_window12_192
# swinv2_large_window12to16_192to256
# swinv2_large_window12to24_192to384
# swinv2_small_window8_256
# swinv2_small_window16_256
# swinv2_tiny_window8_256
# swinv2_tiny_window16_256

# %%
# !rm -rf /content/yolov5/Pascal-Voc-2007-1

# %%
import torch, sys, os
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Torch: 2.9.0+cu126
# CUDA available: True

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.1.46)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.16.3)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (0.24.0+cu126)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (8.4.7)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 42)) (25.0)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 43)) (75.2.0)
# Requirement already satisfied: urllib3>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 51)) (2.6.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.5.0)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (1.31.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (2.0.18)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.3)

# %%
# Download YOLOv5 small pretrained weights
# !wget https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# Out:
# --2026-01-25 13:44:12--  https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/264818686/381bd8a8-8910-4e9e-b0dd-2752951ef78c?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-25T14%3A22%3A57Z&rscd=attachment%3B+filename%3Dyolov5s.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-25T13%3A22%3A11Z&ske=2026-01-25T14%3A22%3A57Z&sks=b&skv=2018-11-09&sig=FL21wTlHuwaNHHJwJ4bMHN483%2FxVAevGP19KM0Y2PjQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2OTM1MDM1MywibmJmIjoxNzY5MzQ4NTUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1XblmckbzTo4mPKVe-tRcyntDPLGvPsB76A_3-vRkCY&response-content-disposition=attachment%3B%20filename%3Dyolov5s.pt&response-content-type=application%2Foctet-stream [following]
# --2026-01-25 13:44:12--  https://release-assets.githubusercontent.com/github-production-release-asset/264818686/381bd8a8-8910-4e9e-b0dd-2752951ef78c?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-01-25T14%3A22%3A57Z&rscd=attachment%3B+filename%3Dyolov5s.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-01-25T13%3A22%3A11Z&ske=2026-01-25T14%3A22%3A57Z&sks=b&skv=2018-11-09&sig=FL21wTlHuwaNHHJwJ4bMHN483%2FxVAevGP19KM0Y2PjQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2OTM1MDM1MywibmJmIjoxNzY5MzQ4NTUzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1XblmckbzTo4mPKVe-tRcyntDPLGvPsB76A_3-vRkCY&response-content-disposition=attachment%3B%20filename%3Dyolov5s.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14808437 (14M) [application/octet-stream]
# Saving to: ‘yolov5s.pt.2’
#
# yolov5s.pt.2        100%[===================>]  14.12M  --.-KB/s    in 0.08s
#
# 2026-01-25 13:44:13 (181 MB/s) - ‘yolov5s.pt.2’ saved [14808437/14808437]

# %%
import os
assert os.path.exists("yolov5s.pt"), "❌ yolov5s.pt not found!"
print("✅ yolov5s.pt found")
# Out:
# ✅ yolov5s.pt found

# %%
# !pip install roboflow
from roboflow import Roboflow

rf = Roboflow(api_key="GYiLvqoCXhBZ3NWSGyrR")
project = rf.workspace("modd2").project("pascal-voc-2007-bhjgf")
dataset = project.version(1).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.1.4)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Pascal-Voc-2007-1 to yolov5pytorch:: 100%|██████████| 308572/308572 [00:04<00:00, 69967.97it/s]
# Extracting Dataset Version Zip to Pascal-Voc-2007-1 in yolov5pytorch:: 100%|██████████| 10026/10026 [00:01<00:00, 5031.08it/s]

# %%
import yaml
from pathlib import Path

data_yaml = Path("/content/yolov5/Pascal-Voc-2007-1/data.yaml")

with open(data_yaml) as f:
    data = yaml.safe_load(f)

root = "/content/Pascal-Voc-2007-1"
data["train"] = f"{root}/train/images"
data["val"]   = f"{root}/valid/images"
data["test"]  = f"{root}/test/images"

with open(data_yaml, "w") as f:
    yaml.safe_dump(data, f)

print("✅ Dataset paths fixed")
# Out:
# ✅ Dataset paths fixed

# %%
# swin_yolov5_pascal2007_base_fs.py
# ------------------------------------------------------------
# Swin backbone + Feature Selection + YOLOv5 pretrained Detect
# ------------------------------------------------------------

import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import timm
from models.yolo import Detect


# ------------------------------------------------------------
# FEATURE SELECTION MODULE
# ------------------------------------------------------------
class FeatureSelector(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channels, channels // reduction, 1, bias=False)
        self.fc2 = nn.Conv2d(channels // reduction, channels, 1, bias=False)
        self.act = nn.Sigmoid()

    def forward(self, x):
        w = self.pool(x)
        w = self.fc1(w)
        w = F.relu(w, inplace=True)
        w = self.fc2(w)
        w = self.act(w)
        return x + x * w


# ------------------------------------------------------------
# SWIN BACKBONE
# ------------------------------------------------------------
class SwinBackbone(nn.Module):
    def __init__(self, variant="swinv2_tiny_window8_256"):
        super().__init__()

        self.swin = timm.create_model(
            variant,
            pretrained=True,
            features_only=True,
            out_indices=(1, 2, 3),
        )

        self.cv3 = nn.Conv2d(192, 256, 1)
        self.cv4 = nn.Conv2d(384, 512, 1)
        self.cv5 = nn.Conv2d(768, 1024, 1)

        self.required_multiple = 8 * 16  # window8 × downsample16

    def forward(self, x):
        B, C, H, W = x.shape
        m = self.required_multiple

        pad_h = (math.ceil(H / m) * m) - H
        pad_w = (math.ceil(W / m) * m) - W
        if pad_h or pad_w:
            x = F.pad(x, (0, pad_w, 0, pad_h))

        f = self.swin(x)

        p3 = self.cv3(f[0].permute(0, 3, 1, 2))
        p4 = self.cv4(f[1].permute(0, 3, 1, 2))
        p5 = self.cv5(f[2].permute(0, 3, 1, 2))

        return [p3, p4, p5]


# ------------------------------------------------------------
# SWIN + FEATURE SELECTION + YOLOv5 DETECT
# ------------------------------------------------------------
class SwinYOLO(nn.Module):
    def __init__(self, nc=20, anchors=None):
        super().__init__()

        self.backbone = SwinBackbone()

        self.fs_p3 = FeatureSelector(256)
        # self.fs_p4 = FeatureSelector(512)
        # self.fs_p5 = FeatureSelector(1024)

        self.detect = Detect(
            nc=nc,
            anchors=anchors,
            ch=[256, 512, 1024],
        )

        self.detect.stride = torch.tensor([8., 16., 32.])

        # --------------------------------------------------
        # YOLOv5-COMPATIBILITY ATTRIBUTES
        # --------------------------------------------------
        self.model = nn.ModuleList([self.backbone, self.detect])
        self.nc = nc
        self.names = [str(i) for i in range(nc)]

    def forward(self, x, augment=False):
        p3, p4, p5 = self.backbone(x)

        p3 = self.fs_p3(p3)
        # p4 = self.fs_p4(p4)
        # p5 = self.fs_p5(p5)

        return self.detect([p3, p4, p5])


# ------------------------------------------------------------
# LOAD PRETRAINED YOLOv5 DETECT WEIGHTS
# ------------------------------------------------------------
def load_yolov5_detect(model, weights="yolov5s.pt"):
    ckpt = torch.load(weights, map_location="cpu", weights_only=False)
    state = ckpt["model"].float().state_dict()

    detect_state = {}
    for k, v in state.items():
        if k.startswith("model.24."):
            new_k = k.replace("model.24.", "")
            if new_k in model.detect.state_dict() and \
               v.shape == model.detect.state_dict()[new_k].shape:
                detect_state[new_k] = v

    model.detect.load_state_dict(detect_state, strict=False)
    print(f"✅ Loaded {len(detect_state)} pretrained Detect layers")


# ------------------------------------------------------------
# SANITY CHECK
# ------------------------------------------------------------
if __name__ == "__main__":
    anchors = [
        [10,13, 16,30, 33,23],
        [30,61, 62,45, 59,119],
        [116,90, 156,198, 373,326],
    ]

    model = SwinYOLO(nc=20, anchors=anchors)
    load_yolov5_detect(model)

    x = torch.zeros(1, 3, 256, 256)
    y = model(x)

    print("✅ Forward pass successful")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# model.safetensors:   0%|          | 0.00/115M [00:00<?, ?B/s]
# ✅ Loaded 1 pretrained Detect layers
# ✅ Forward pass successful

# %%
print("Detect nc:", model.detect.nc)
print("Detect anchors:", model.detect.anchors)
print("Detect stride:", model.detect.stride)
for i, m in enumerate(model.detect.m):
    print(f"Detect scale {i} input channels:", m.weight.shape[1])
# Out:
# Detect nc: 20
# Detect anchors: tensor([[[ 1.25000,  1.62500],
#          [ 2.00000,  3.75000],
#          [ 4.12500,  2.87500]],
#
#         [[ 1.87500,  3.81250],
#          [ 3.87500,  2.81250],
#          [ 3.68750,  7.43750]],
#
#         [[ 3.62500,  2.81250],
#          [ 4.87500,  6.18750],
#          [11.65625, 10.18750]]])
# Detect stride: tensor([ 8., 16., 32.])
# Detect scale 0 input channels: 256
# Detect scale 1 input channels: 512
# Detect scale 2 input channels: 1024

# %%
x = torch.zeros(1, 3, 256, 256)
y = model(x)

for i, out in enumerate(y):
    print(f"Scale {i} output shape:", out.shape)
# Out:
# Scale 0 output shape: torch.Size([1, 3, 32, 32, 25])
# Scale 1 output shape: torch.Size([1, 3, 16, 16, 25])
# Scale 2 output shape: torch.Size([1, 3, 8, 8, 25])

# %%
x = torch.randn(2, 3, 256, 256)
y = model(x)

loss = sum(o.sum() for o in y)
loss.backward()

print("✅ Backward pass successful")
# Out:
# ✅ Backward pass successful

# %%
# !python swin_yolov5_pascal2007_base_fs.py
# Out:
# ✅ Loaded 1 pretrained Detect layers
# ✅ Forward pass successful

# %%
# !python -c "import timm; print(timm.__version__)"
# Out:
# 1.0.24

# %%
# train_swin_yolo.py
# train_swin_yolo.py
import torch
import yaml
from pathlib import Path
from tqdm import tqdm
import sys
from copy import deepcopy

# ------------------------------------------------------------
# PATHS
# ------------------------------------------------------------
YOLO_ROOT = Path("/content/yolov5")
DATA_YAML = "/content/yolov5/Pascal-Voc-2007-1/data.yaml"
HYP_YAML = "/content/yolov5/data/hyps/hyp.scratch-low.yaml"

sys.path.append(str(YOLO_ROOT))

# ------------------------------------------------------------
# YOLOv5 IMPORTS
# ------------------------------------------------------------
from utils.dataloaders import create_dataloader
from utils.loss import ComputeLoss
from val import run as val_run
from utils.torch_utils import select_device

# ------------------------------------------------------------
# OUR MODEL
# ------------------------------------------------------------
from swin_yolov5_pascal2007_base_fs import SwinYOLO, load_yolov5_detect

# ------------------------------------------------------------
# TRAINING CONFIG
# ------------------------------------------------------------
IMG_SIZE = 256
BATCH_SIZE = 8
EPOCHS = 40

LR = 2e-4
FREEZE_EPOCHS = 5

DEVICE = select_device("0" if torch.cuda.is_available() else "cpu")

# ------------------------------------------------------------
# LOAD DATA + HYP
# ------------------------------------------------------------
with open(DATA_YAML) as f:
    data = yaml.safe_load(f)

with open(HYP_YAML) as f:
    hyp = yaml.safe_load(f)

nc = int(data["nc"])

# ------------------------------------------------------------
# BUILD MODEL
# ------------------------------------------------------------
anchors = [
    [10, 13, 16, 30, 33, 23],
    [30, 61, 62, 45, 59, 119],
    [116, 90, 156, 198, 373, 326],
]

model = SwinYOLO(nc=nc, anchors=anchors).to(DEVICE)
load_yolov5_detect(model)

# REQUIRED by ComputeLoss
model.hyp = hyp
model.train()

# ------------------------------------------------------------
# FREEZE BACKBONE (WARMUP)
# ------------------------------------------------------------
for p in model.backbone.parameters():
    p.requires_grad = False

print(f"🔒 Swin backbone frozen for first {FREEZE_EPOCHS} epochs")

# ------------------------------------------------------------
# DATALOADERS
# ------------------------------------------------------------
train_loader, _ = create_dataloader(
    path=data["train"],
    imgsz=IMG_SIZE,
    batch_size=BATCH_SIZE,
    stride=32,
    single_cls=False,
    hyp=hyp,
    augment=True,
    cache=False,
    rect=False,
    rank=-1,
    workers=4,
)

val_loader, _ = create_dataloader(
    path=data["val"],
    imgsz=IMG_SIZE,
    batch_size=BATCH_SIZE,
    stride=32,
    single_cls=False,
    hyp=hyp,
    augment=False,
    cache=False,
    rect=True,
    rank=-1,
    workers=4,
)

# ------------------------------------------------------------
# LOSS + OPTIMIZER
# ------------------------------------------------------------
compute_loss = ComputeLoss(model)

optimizer = torch.optim.SGD(
    model.parameters(),
    lr=LR,
    momentum=0.9,
    weight_decay=5e-4
)

# ------------------------------------------------------------
# TRAIN LOOP
# ------------------------------------------------------------
for epoch in range(EPOCHS):

    # 🔓 Unfreeze backbone automatically
    if epoch == FREEZE_EPOCHS:
        print("🔓 Unfreezing Swin backbone")
        for p in model.backbone.parameters():
            p.requires_grad = True

    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}")
    mloss = torch.zeros(3, device=DEVICE)

    # -------------------- TRAIN --------------------
    for imgs, targets, paths, _ in pbar:
        imgs = imgs.to(DEVICE).float() / 255.0
        targets = targets.to(DEVICE)

        preds = model(imgs)
        loss, loss_items = compute_loss(preds, targets)

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 10.0)
        optimizer.step()

        mloss = mloss * 0.9 + loss_items * 0.1

        pbar.set_postfix(
            box=f"{mloss[0]:.3f}",
            obj=f"{mloss[1]:.3f}",
            cls=f"{mloss[2]:.3f}",
            total=f"{loss.item():.3f}",
        )

    print(f"Epoch {epoch+1}/{EPOCHS} | loss: {loss.item():.4f}")

    # --------------------------------------------------------
    # VALIDATION (SAFE, AUTOGRAD-PROOF)
    # --------------------------------------------------------
    model.eval()

    with torch.no_grad():
        eval_model = deepcopy(model).to(DEVICE)

        results, maps, _ = val_run(
            data=data,
            model=eval_model,
            dataloader=val_loader,
            imgsz=IMG_SIZE,
            conf_thres=0.001,
            iou_thres=0.6,
            device=DEVICE,
            single_cls=False,
            save_json=False,
            verbose=False,
        )

    del eval_model
    torch.cuda.empty_cache()

    model.train()
    torch.set_grad_enabled(True)

    P, R, mAP50, mAP5095 = results[:4]
    print(
        f"📊 Val | "
        f"P: {P:.4f} | "
        f"R: {R:.4f} | "
        f"mAP@0.5: {mAP50:.4f} | "
        f"mAP@0.5:0.95: {mAP5095:.4f}"
    )

print("\n✅ Training complete")

# %%
# !python train_swin_yolo.py
# Out:
# YOLOv5 🚀 v7.0-457-g84ef1e59 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# ✅ Loaded 1 pretrained Detect layers
# 🔒 Swin backbone frozen for first 5 epochs
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# Scanning /content/yolov5/Pascal-Voc-2007-1/train/labels... 3506 images, 32 backgrounds, 0 corrupt: 100% 3506/3506 [00:01<00:00, 1960.79it/s]
# New cache created: /content/yolov5/Pascal-Voc-2007-1/train/labels.cache
# Scanning /content/yolov5/Pascal-Voc-2007-1/valid/labels... 1001 images, 6 backgrounds, 0 corrupt: 100% 1001/1001 [00:00<00:00, 1305.20it/s]
# New cache created: /content/yolov5/Pascal-Voc-2007-1/valid/labels.cache
# Epoch 1/40: 100% 439/439 [00:50<00:00,  8.66it/s, box=0.105, cls=0.538, obj=0.208, total=1.759]
# Epoch 1/40 | loss: 1.7591
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.5MB/s 0.0s
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:59<00:00,  2.10it/s]
#                    all       1001       3021     0.0038     0.0433    0.00164   0.000472
# 📊 Val | P: 0.0038 | R: 0.0433 | mAP@0.5: 0.0016 | mAP@0.5:0.95: 0.0005
# Epoch 2/40: 100% 439/439 [00:48<00:00,  9.01it/s, box=0.103, cls=0.411, obj=0.196, total=1.413]
# Epoch 2/40 | loss: 1.4134
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:45<00:00,  2.74it/s]
#                    all       1001       3021    0.00354     0.0556    0.00185   0.000509
# 📊 Val | P: 0.0035 | R: 0.0556 | mAP@0.5: 0.0019 | mAP@0.5:0.95: 0.0005
# Epoch 3/40: 100% 439/439 [00:49<00:00,  8.88it/s, box=0.102, cls=0.373, obj=0.198, total=1.404]
# Epoch 3/40 | loss: 1.4043
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:35<00:00,  3.53it/s]
#                    all       1001       3021    0.00447     0.0497    0.00241   0.000631
# 📊 Val | P: 0.0045 | R: 0.0497 | mAP@0.5: 0.0024 | mAP@0.5:0.95: 0.0006
# Epoch 4/40: 100% 439/439 [00:49<00:00,  8.90it/s, box=0.094, cls=0.320, obj=0.197, total=0.701]
# Epoch 4/40 | loss: 0.7008
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:28<00:00,  4.37it/s]
#                    all       1001       3021    0.00575     0.0407    0.00278   0.000752
# 📊 Val | P: 0.0057 | R: 0.0407 | mAP@0.5: 0.0028 | mAP@0.5:0.95: 0.0008
# Epoch 5/40: 100% 439/439 [00:49<00:00,  8.95it/s, box=0.098, cls=0.326, obj=0.186, total=0.965]
# Epoch 5/40 | loss: 0.9654
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:25<00:00,  4.99it/s]
#                    all       1001       3021    0.00626     0.0299    0.00353   0.000901
# 📊 Val | P: 0.0063 | R: 0.0299 | mAP@0.5: 0.0035 | mAP@0.5:0.95: 0.0009
# 🔓 Unfreezing Swin backbone
# Epoch 6/40: 100% 439/439 [01:22<00:00,  5.34it/s, box=0.094, cls=0.229, obj=0.185, total=0.979]
# Epoch 6/40 | loss: 0.9785
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.31it/s]
#                    all       1001       3021     0.0619     0.0845     0.0341    0.00781
# 📊 Val | P: 0.0619 | R: 0.0845 | mAP@0.5: 0.0341 | mAP@0.5:0.95: 0.0078
# Epoch 7/40: 100% 439/439 [01:21<00:00,  5.35it/s, box=0.092, cls=0.219, obj=0.175, total=0.993]
# Epoch 7/40 | loss: 0.9933
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.27it/s]
#                    all       1001       3021       0.19      0.168     0.0563     0.0132
# 📊 Val | P: 0.1899 | R: 0.1680 | mAP@0.5: 0.0563 | mAP@0.5:0.95: 0.0132
# Epoch 8/40: 100% 439/439 [01:22<00:00,  5.30it/s, box=0.093, cls=0.208, obj=0.180, total=0.945]
# Epoch 8/40 | loss: 0.9448
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.44it/s]
#                    all       1001       3021      0.193      0.213     0.0833     0.0189
# 📊 Val | P: 0.1932 | R: 0.2132 | mAP@0.5: 0.0833 | mAP@0.5:0.95: 0.0189
# Epoch 9/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.090, cls=0.196, obj=0.197, total=1.120]
# Epoch 9/40 | loss: 1.1198
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.59it/s]
#                    all       1001       3021      0.205      0.223     0.0933     0.0225
# 📊 Val | P: 0.2046 | R: 0.2230 | mAP@0.5: 0.0933 | mAP@0.5:0.95: 0.0225
# Epoch 10/40: 100% 439/439 [01:23<00:00,  5.27it/s, box=0.090, cls=0.190, obj=0.186, total=0.866]
# Epoch 10/40 | loss: 0.8663
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.61it/s]
#                    all       1001       3021      0.203      0.262      0.112     0.0272
# 📊 Val | P: 0.2028 | R: 0.2619 | mAP@0.5: 0.1117 | mAP@0.5:0.95: 0.0272
# Epoch 11/40: 100% 439/439 [01:21<00:00,  5.39it/s, box=0.083, cls=0.171, obj=0.168, total=0.420]
# Epoch 11/40 | loss: 0.4204
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.86it/s]
#                    all       1001       3021      0.201      0.265      0.126     0.0305
# 📊 Val | P: 0.2014 | R: 0.2651 | mAP@0.5: 0.1255 | mAP@0.5:0.95: 0.0305
# Epoch 12/40: 100% 439/439 [01:21<00:00,  5.36it/s, box=0.087, cls=0.185, obj=0.193, total=1.027]
# Epoch 12/40 | loss: 1.0272
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:09<00:00, 12.62it/s]
#                    all       1001       3021      0.225      0.275       0.15      0.039
# 📊 Val | P: 0.2248 | R: 0.2748 | mAP@0.5: 0.1500 | mAP@0.5:0.95: 0.0390
# Epoch 13/40: 100% 439/439 [01:21<00:00,  5.38it/s, box=0.085, cls=0.187, obj=0.190, total=1.342]
# Epoch 13/40 | loss: 1.3416
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.57it/s]
#                    all       1001       3021      0.219        0.3      0.162     0.0398
# 📊 Val | P: 0.2192 | R: 0.3003 | mAP@0.5: 0.1620 | mAP@0.5:0.95: 0.0398
# Epoch 14/40: 100% 439/439 [01:22<00:00,  5.35it/s, box=0.087, cls=0.162, obj=0.199, total=0.909]
# Epoch 14/40 | loss: 0.9094
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.32it/s]
#                    all       1001       3021      0.197      0.275      0.147     0.0351
# 📊 Val | P: 0.1972 | R: 0.2745 | mAP@0.5: 0.1468 | mAP@0.5:0.95: 0.0351
# Epoch 15/40: 100% 439/439 [01:21<00:00,  5.39it/s, box=0.080, cls=0.156, obj=0.172, total=0.328]
# Epoch 15/40 | loss: 0.3280
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.59it/s]
#                    all       1001       3021      0.265      0.303      0.182     0.0491
# 📊 Val | P: 0.2654 | R: 0.3028 | mAP@0.5: 0.1816 | mAP@0.5:0.95: 0.0491
# Epoch 16/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.084, cls=0.172, obj=0.181, total=0.822]
# Epoch 16/40 | loss: 0.8218
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.62it/s]
#                    all       1001       3021      0.257      0.304      0.189     0.0506
# 📊 Val | P: 0.2567 | R: 0.3039 | mAP@0.5: 0.1885 | mAP@0.5:0.95: 0.0506
# Epoch 17/40: 100% 439/439 [01:22<00:00,  5.34it/s, box=0.086, cls=0.159, obj=0.187, total=0.745]
# Epoch 17/40 | loss: 0.7453
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.77it/s]
#                    all       1001       3021      0.246      0.297      0.184     0.0461
# 📊 Val | P: 0.2462 | R: 0.2971 | mAP@0.5: 0.1843 | mAP@0.5:0.95: 0.0461
# Epoch 18/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.083, cls=0.147, obj=0.174, total=0.780]
# Epoch 18/40 | loss: 0.7795
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.52it/s]
#                    all       1001       3021      0.267      0.307      0.205     0.0545
# 📊 Val | P: 0.2667 | R: 0.3065 | mAP@0.5: 0.2054 | mAP@0.5:0.95: 0.0545
# Epoch 19/40: 100% 439/439 [01:22<00:00,  5.34it/s, box=0.082, cls=0.170, obj=0.192, total=1.007]
# Epoch 19/40 | loss: 1.0070
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.30it/s]
#                    all       1001       3021      0.301      0.312      0.224      0.059
# 📊 Val | P: 0.3006 | R: 0.3122 | mAP@0.5: 0.2240 | mAP@0.5:0.95: 0.0590
# Epoch 20/40: 100% 439/439 [01:21<00:00,  5.35it/s, box=0.083, cls=0.153, obj=0.187, total=0.510]
# Epoch 20/40 | loss: 0.5104
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.31it/s]
#                    all       1001       3021      0.329      0.313      0.233     0.0656
# 📊 Val | P: 0.3286 | R: 0.3130 | mAP@0.5: 0.2335 | mAP@0.5:0.95: 0.0656
# Epoch 21/40: 100% 439/439 [01:22<00:00,  5.34it/s, box=0.084, cls=0.155, obj=0.197, total=1.000]
# Epoch 21/40 | loss: 1.0002
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.58it/s]
#                    all       1001       3021      0.367      0.306      0.237     0.0673
# 📊 Val | P: 0.3671 | R: 0.3058 | mAP@0.5: 0.2371 | mAP@0.5:0.95: 0.0673
# Epoch 22/40: 100% 439/439 [01:21<00:00,  5.41it/s, box=0.082, cls=0.152, obj=0.191, total=0.845]
# Epoch 22/40 | loss: 0.8451
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.52it/s]
#                    all       1001       3021      0.323      0.328      0.249     0.0693
# 📊 Val | P: 0.3226 | R: 0.3283 | mAP@0.5: 0.2491 | mAP@0.5:0.95: 0.0693
# Epoch 23/40: 100% 439/439 [01:21<00:00,  5.35it/s, box=0.082, cls=0.161, obj=0.172, total=1.015]
# Epoch 23/40 | loss: 1.0146
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.41it/s]
#                    all       1001       3021      0.353      0.313       0.26     0.0748
# 📊 Val | P: 0.3535 | R: 0.3133 | mAP@0.5: 0.2604 | mAP@0.5:0.95: 0.0748
# Epoch 24/40: 100% 439/439 [01:21<00:00,  5.41it/s, box=0.080, cls=0.146, obj=0.177, total=0.542]
# Epoch 24/40 | loss: 0.5417
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.34it/s]
#                    all       1001       3021      0.369      0.319      0.252     0.0719
# 📊 Val | P: 0.3688 | R: 0.3190 | mAP@0.5: 0.2519 | mAP@0.5:0.95: 0.0719
# Epoch 25/40: 100% 439/439 [01:22<00:00,  5.35it/s, box=0.082, cls=0.149, obj=0.184, total=0.819]
# Epoch 25/40 | loss: 0.8189
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.49it/s]
#                    all       1001       3021      0.335      0.331      0.254     0.0713
# 📊 Val | P: 0.3352 | R: 0.3308 | mAP@0.5: 0.2545 | mAP@0.5:0.95: 0.0713
# Epoch 26/40: 100% 439/439 [01:21<00:00,  5.41it/s, box=0.082, cls=0.151, obj=0.181, total=0.815]
# Epoch 26/40 | loss: 0.8148
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.25it/s]
#                    all       1001       3021      0.375      0.344      0.279     0.0829
# 📊 Val | P: 0.3752 | R: 0.3438 | mAP@0.5: 0.2793 | mAP@0.5:0.95: 0.0829
# Epoch 27/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.080, cls=0.158, obj=0.173, total=1.110]
# Epoch 27/40 | loss: 1.1097
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.23it/s]
#                    all       1001       3021      0.373      0.331      0.272      0.078
# 📊 Val | P: 0.3734 | R: 0.3312 | mAP@0.5: 0.2717 | mAP@0.5:0.95: 0.0780
# Epoch 28/40: 100% 439/439 [01:21<00:00,  5.38it/s, box=0.077, cls=0.142, obj=0.182, total=0.400]
# Epoch 28/40 | loss: 0.4004
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.78it/s]
#                    all       1001       3021      0.341      0.325      0.276     0.0829
# 📊 Val | P: 0.3413 | R: 0.3249 | mAP@0.5: 0.2758 | mAP@0.5:0.95: 0.0829
# Epoch 29/40: 100% 439/439 [01:21<00:00,  5.38it/s, box=0.081, cls=0.136, obj=0.189, total=0.790]
# Epoch 29/40 | loss: 0.7901
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.20it/s]
#                    all       1001       3021      0.383      0.332       0.28     0.0824
# 📊 Val | P: 0.3829 | R: 0.3324 | mAP@0.5: 0.2796 | mAP@0.5:0.95: 0.0824
# Epoch 30/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.079, cls=0.145, obj=0.192, total=0.824]
# Epoch 30/40 | loss: 0.8243
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.41it/s]
#                    all       1001       3021      0.385       0.35      0.292     0.0933
# 📊 Val | P: 0.3848 | R: 0.3503 | mAP@0.5: 0.2923 | mAP@0.5:0.95: 0.0933
# Epoch 31/40: 100% 439/439 [01:21<00:00,  5.38it/s, box=0.080, cls=0.140, obj=0.175, total=0.778]
# Epoch 31/40 | loss: 0.7783
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.43it/s]
#                    all       1001       3021      0.358      0.362      0.288     0.0859
# 📊 Val | P: 0.3579 | R: 0.3625 | mAP@0.5: 0.2877 | mAP@0.5:0.95: 0.0859
# Epoch 32/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.079, cls=0.141, obj=0.174, total=0.607]
# Epoch 32/40 | loss: 0.6067
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.04it/s]
#                    all       1001       3021      0.363       0.37       0.31     0.0949
# 📊 Val | P: 0.3634 | R: 0.3697 | mAP@0.5: 0.3105 | mAP@0.5:0.95: 0.0949
# Epoch 33/40: 100% 439/439 [01:22<00:00,  5.31it/s, box=0.081, cls=0.145, obj=0.188, total=0.866]
# Epoch 33/40 | loss: 0.8662
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.08it/s]
#                    all       1001       3021      0.405      0.353      0.308     0.0916
# 📊 Val | P: 0.4048 | R: 0.3527 | mAP@0.5: 0.3081 | mAP@0.5:0.95: 0.0916
# Epoch 34/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.076, cls=0.132, obj=0.181, total=0.487]
# Epoch 34/40 | loss: 0.4872
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.24it/s]
#                    all       1001       3021       0.37      0.371      0.315      0.103
# 📊 Val | P: 0.3702 | R: 0.3709 | mAP@0.5: 0.3147 | mAP@0.5:0.95: 0.1029
# Epoch 35/40: 100% 439/439 [01:22<00:00,  5.33it/s, box=0.079, cls=0.138, obj=0.191, total=0.836]
# Epoch 35/40 | loss: 0.8362
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:09<00:00, 12.62it/s]
#                    all       1001       3021      0.395      0.353      0.317      0.102
# 📊 Val | P: 0.3947 | R: 0.3534 | mAP@0.5: 0.3166 | mAP@0.5:0.95: 0.1025
# Epoch 36/40: 100% 439/439 [01:21<00:00,  5.39it/s, box=0.080, cls=0.134, obj=0.172, total=0.679]
# Epoch 36/40 | loss: 0.6794
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.63it/s]
#                    all       1001       3021      0.359      0.365      0.304     0.0919
# 📊 Val | P: 0.3587 | R: 0.3649 | mAP@0.5: 0.3041 | mAP@0.5:0.95: 0.0919
# Epoch 37/40: 100% 439/439 [01:21<00:00,  5.35it/s, box=0.076, cls=0.136, obj=0.174, total=0.476]
# Epoch 37/40 | loss: 0.4761
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.24it/s]
#                    all       1001       3021      0.398      0.367      0.328      0.112
# 📊 Val | P: 0.3980 | R: 0.3668 | mAP@0.5: 0.3278 | mAP@0.5:0.95: 0.1118
# Epoch 38/40: 100% 439/439 [01:21<00:00,  5.39it/s, box=0.079, cls=0.140, obj=0.195, total=0.886]
# Epoch 38/40 | loss: 0.8863
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.27it/s]
#                    all       1001       3021      0.405      0.352      0.309     0.0986
# 📊 Val | P: 0.4047 | R: 0.3524 | mAP@0.5: 0.3095 | mAP@0.5:0.95: 0.0986
# Epoch 39/40: 100% 439/439 [01:21<00:00,  5.39it/s, box=0.079, cls=0.136, obj=0.183, total=0.863]
# Epoch 39/40 | loss: 0.8630
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.58it/s]
#                    all       1001       3021      0.397      0.364      0.323     0.0979
# 📊 Val | P: 0.3967 | R: 0.3642 | mAP@0.5: 0.3226 | mAP@0.5:0.95: 0.0979
# Epoch 40/40: 100% 439/439 [01:21<00:00,  5.36it/s, box=0.078, cls=0.133, obj=0.187, total=0.656]
# Epoch 40/40 | loss: 0.6562
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.39it/s]
#                    all       1001       3021      0.411      0.355      0.327      0.106
# 📊 Val | P: 0.4112 | R: 0.3555 | mAP@0.5: 0.3272 | mAP@0.5:0.95: 0.1055
#
# ✅ Training complete

# %%
# !python train_swin_yolo_all.py
# Out:
# YOLOv5 🚀 v7.0-457-g84ef1e59 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# ✅ Loaded 1 pretrained Detect layers
# 🔒 Swin backbone frozen for first 5 epochs
# albumentations: 1 validation error for InitSchema
# size
#   Field required [type=missing, input_value={'scale': (0.8, 1.0), 'ra...: None, 'strict': False}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# Scanning /content/yolov5/Pascal-Voc-2007-1/train/labels.cache... 3506 images, 32 backgrounds, 0 corrupt: 100% 3506/3506 [00:00<?, ?it/s]
# Scanning /content/yolov5/Pascal-Voc-2007-1/valid/labels.cache... 1001 images, 6 backgrounds, 0 corrupt: 100% 1001/1001 [00:00<?, ?it/s]
# Epoch 1/40: 100% 439/439 [00:48<00:00,  8.98it/s, box=0.109, cls=0.496, obj=0.188, total=1.631]
# Epoch 1/40 | loss: 1.6307
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:56<00:00,  2.23it/s]
#                    all       1001       3021    0.00284     0.0477    0.00134   0.000359
# 📊 Val | P: 0.0028 | R: 0.0477 | mAP@0.5: 0.0013 | mAP@0.5:0.95: 0.0004
# Epoch 2/40: 100% 439/439 [00:48<00:00,  9.01it/s, box=0.107, cls=0.384, obj=0.180, total=1.409]
# Epoch 2/40 | loss: 1.4089
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:35<00:00,  3.53it/s]
#                    all       1001       3021    0.00387     0.0493    0.00191   0.000503
# 📊 Val | P: 0.0039 | R: 0.0493 | mAP@0.5: 0.0019 | mAP@0.5:0.95: 0.0005
# Epoch 3/40: 100% 439/439 [00:49<00:00,  8.95it/s, box=0.104, cls=0.346, obj=0.181, total=1.335]
# Epoch 3/40 | loss: 1.3351
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:26<00:00,  4.75it/s]
#                    all       1001       3021    0.00667     0.0477    0.00338   0.000869
# 📊 Val | P: 0.0067 | R: 0.0477 | mAP@0.5: 0.0034 | mAP@0.5:0.95: 0.0009
# Epoch 4/40: 100% 439/439 [00:48<00:00,  8.98it/s, box=0.097, cls=0.297, obj=0.181, total=0.617]
# Epoch 4/40 | loss: 0.6171
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:22<00:00,  5.72it/s]
#                    all       1001       3021     0.0102     0.0589    0.00462    0.00114
# 📊 Val | P: 0.0102 | R: 0.0589 | mAP@0.5: 0.0046 | mAP@0.5:0.95: 0.0011
# Epoch 5/40: 100% 439/439 [00:49<00:00,  8.91it/s, box=0.100, cls=0.291, obj=0.175, total=1.024]
# Epoch 5/40 | loss: 1.0239
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:19<00:00,  6.54it/s]
#                    all       1001       3021     0.0147     0.0625    0.00707    0.00175
# 📊 Val | P: 0.0147 | R: 0.0625 | mAP@0.5: 0.0071 | mAP@0.5:0.95: 0.0018
# 🔓 Unfreezing Swin backbone
# Epoch 6/40: 100% 439/439 [01:21<00:00,  5.36it/s, box=0.096, cls=0.212, obj=0.181, total=0.921]
# Epoch 6/40 | loss: 0.9210
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.78it/s]
#                    all       1001       3021     0.0735      0.156     0.0543     0.0124
# 📊 Val | P: 0.0735 | R: 0.1562 | mAP@0.5: 0.0543 | mAP@0.5:0.95: 0.0124
# Epoch 7/40: 100% 439/439 [01:21<00:00,  5.37it/s, box=0.094, cls=0.200, obj=0.168, total=0.870]
# Epoch 7/40 | loss: 0.8703
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.86it/s]
#                    all       1001       3021      0.107      0.192      0.061     0.0139
# 📊 Val | P: 0.1072 | R: 0.1920 | mAP@0.5: 0.0610 | mAP@0.5:0.95: 0.0139
# Epoch 8/40: 100% 439/439 [01:22<00:00,  5.33it/s, box=0.094, cls=0.198, obj=0.180, total=0.945]
# Epoch 8/40 | loss: 0.9447
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:09<00:00, 12.84it/s]
#                    all       1001       3021      0.156      0.207      0.105     0.0272
# 📊 Val | P: 0.1562 | R: 0.2073 | mAP@0.5: 0.1046 | mAP@0.5:0.95: 0.0272
# Epoch 9/40: 100% 439/439 [01:21<00:00,  5.36it/s, box=0.090, cls=0.182, obj=0.196, total=1.081]
# Epoch 9/40 | loss: 1.0814
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.86it/s]
#                    all       1001       3021       0.25      0.236      0.115     0.0288
# 📊 Val | P: 0.2502 | R: 0.2360 | mAP@0.5: 0.1150 | mAP@0.5:0.95: 0.0288
# Epoch 10/40: 100% 439/439 [01:22<00:00,  5.32it/s, box=0.091, cls=0.178, obj=0.184, total=0.871]
# Epoch 10/40 | loss: 0.8707
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:09<00:00, 12.69it/s]
#                    all       1001       3021      0.224      0.247       0.12     0.0303
# 📊 Val | P: 0.2242 | R: 0.2467 | mAP@0.5: 0.1202 | mAP@0.5:0.95: 0.0303
# Epoch 11/40: 100% 439/439 [01:21<00:00,  5.38it/s, box=0.083, cls=0.161, obj=0.169, total=0.419]
# Epoch 11/40 | loss: 0.4191
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.92it/s]
#                    all       1001       3021      0.204      0.272      0.151      0.042
# 📊 Val | P: 0.2039 | R: 0.2724 | mAP@0.5: 0.1508 | mAP@0.5:0.95: 0.0420
# Epoch 12/40: 100% 439/439 [01:22<00:00,  5.35it/s, box=0.087, cls=0.176, obj=0.192, total=1.008]
# Epoch 12/40 | loss: 1.0076
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 12.21it/s]
#                    all       1001       3021       0.18      0.283      0.131     0.0344
# 📊 Val | P: 0.1800 | R: 0.2832 | mAP@0.5: 0.1305 | mAP@0.5:0.95: 0.0344
# Epoch 13/40: 100% 439/439 [01:22<00:00,  5.35it/s, box=0.085, cls=0.175, obj=0.190, total=1.256]
# Epoch 13/40 | loss: 1.2556
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.78it/s]
#                    all       1001       3021      0.209      0.297      0.167     0.0429
# 📊 Val | P: 0.2092 | R: 0.2965 | mAP@0.5: 0.1668 | mAP@0.5:0.95: 0.0429
# Epoch 14/40: 100% 439/439 [01:22<00:00,  5.30it/s, box=0.086, cls=0.156, obj=0.200, total=0.886]
# Epoch 14/40 | loss: 0.8861
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.20it/s]
#                    all       1001       3021      0.223      0.295       0.18      0.049
# 📊 Val | P: 0.2234 | R: 0.2949 | mAP@0.5: 0.1802 | mAP@0.5:0.95: 0.0490
# Epoch 15/40: 100% 439/439 [01:22<00:00,  5.31it/s, box=0.080, cls=0.144, obj=0.172, total=0.315]
# Epoch 15/40 | loss: 0.3152
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.21it/s]
#                    all       1001       3021      0.261      0.293      0.197     0.0568
# 📊 Val | P: 0.2612 | R: 0.2935 | mAP@0.5: 0.1971 | mAP@0.5:0.95: 0.0568
# Epoch 16/40: 100% 439/439 [01:22<00:00,  5.32it/s, box=0.084, cls=0.160, obj=0.182, total=0.770]
# Epoch 16/40 | loss: 0.7700
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.24it/s]
#                    all       1001       3021      0.259      0.299      0.195      0.053
# 📊 Val | P: 0.2587 | R: 0.2991 | mAP@0.5: 0.1949 | mAP@0.5:0.95: 0.0530
# Epoch 17/40: 100% 439/439 [01:23<00:00,  5.26it/s, box=0.085, cls=0.153, obj=0.186, total=0.725]
# Epoch 17/40 | loss: 0.7249
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.44it/s]
#                    all       1001       3021      0.239      0.313       0.19      0.052
# 📊 Val | P: 0.2394 | R: 0.3135 | mAP@0.5: 0.1903 | mAP@0.5:0.95: 0.0520
# Epoch 18/40: 100% 439/439 [01:25<00:00,  5.13it/s, box=0.082, cls=0.144, obj=0.173, total=0.777]
# Epoch 18/40 | loss: 0.7769
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.86it/s]
#                    all       1001       3021      0.284      0.303      0.225     0.0675
# 📊 Val | P: 0.2836 | R: 0.3030 | mAP@0.5: 0.2251 | mAP@0.5:0.95: 0.0675
# Epoch 19/40: 100% 439/439 [01:24<00:00,  5.20it/s, box=0.081, cls=0.164, obj=0.193, total=1.016]
# Epoch 19/40 | loss: 1.0157
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.49it/s]
#                    all       1001       3021      0.294      0.329      0.239     0.0704
# 📊 Val | P: 0.2945 | R: 0.3292 | mAP@0.5: 0.2392 | mAP@0.5:0.95: 0.0704
# Epoch 20/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.082, cls=0.147, obj=0.187, total=0.526]
# Epoch 20/40 | loss: 0.5265
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.73it/s]
#                    all       1001       3021        0.3      0.324      0.241      0.075
# 📊 Val | P: 0.3003 | R: 0.3243 | mAP@0.5: 0.2410 | mAP@0.5:0.95: 0.0750
# Epoch 21/40: 100% 439/439 [01:24<00:00,  5.20it/s, box=0.083, cls=0.149, obj=0.197, total=0.984]
# Epoch 21/40 | loss: 0.9842
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:10<00:00, 11.79it/s]
#                    all       1001       3021      0.269      0.314      0.214     0.0596
# 📊 Val | P: 0.2693 | R: 0.3143 | mAP@0.5: 0.2143 | mAP@0.5:0.95: 0.0596
# Epoch 22/40: 100% 439/439 [01:23<00:00,  5.25it/s, box=0.081, cls=0.146, obj=0.191, total=0.824]
# Epoch 22/40 | loss: 0.8235
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.37it/s]
#                    all       1001       3021      0.276      0.329      0.221     0.0586
# 📊 Val | P: 0.2764 | R: 0.3291 | mAP@0.5: 0.2208 | mAP@0.5:0.95: 0.0586
# Epoch 23/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.081, cls=0.156, obj=0.173, total=1.017]
# Epoch 23/40 | loss: 1.0169
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.89it/s]
#                    all       1001       3021      0.309      0.326      0.249     0.0789
# 📊 Val | P: 0.3086 | R: 0.3258 | mAP@0.5: 0.2490 | mAP@0.5:0.95: 0.0789
# Epoch 24/40: 100% 439/439 [01:23<00:00,  5.28it/s, box=0.080, cls=0.139, obj=0.177, total=0.526]
# Epoch 24/40 | loss: 0.5264
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.60it/s]
#                    all       1001       3021      0.306      0.336      0.254     0.0737
# 📊 Val | P: 0.3062 | R: 0.3355 | mAP@0.5: 0.2544 | mAP@0.5:0.95: 0.0737
# Epoch 25/40: 100% 439/439 [01:24<00:00,  5.19it/s, box=0.081, cls=0.143, obj=0.185, total=0.762]
# Epoch 25/40 | loss: 0.7625
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.39it/s]
#                    all       1001       3021      0.301      0.336      0.242     0.0674
# 📊 Val | P: 0.3005 | R: 0.3356 | mAP@0.5: 0.2420 | mAP@0.5:0.95: 0.0674
# Epoch 26/40: 100% 439/439 [01:24<00:00,  5.18it/s, box=0.082, cls=0.147, obj=0.182, total=0.840]
# Epoch 26/40 | loss: 0.8401
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.97it/s]
#                    all       1001       3021      0.362      0.339      0.282     0.0898
# 📊 Val | P: 0.3623 | R: 0.3393 | mAP@0.5: 0.2816 | mAP@0.5:0.95: 0.0898
# Epoch 27/40: 100% 439/439 [01:24<00:00,  5.22it/s, box=0.079, cls=0.147, obj=0.173, total=1.013]
# Epoch 27/40 | loss: 1.0130
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.92it/s]
#                    all       1001       3021       0.33      0.361      0.279     0.0843
# 📊 Val | P: 0.3303 | R: 0.3613 | mAP@0.5: 0.2792 | mAP@0.5:0.95: 0.0843
# Epoch 28/40: 100% 439/439 [01:23<00:00,  5.23it/s, box=0.077, cls=0.135, obj=0.183, total=0.381]
# Epoch 28/40 | loss: 0.3806
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.39it/s]
#                    all       1001       3021      0.327      0.336      0.284     0.0887
# 📊 Val | P: 0.3272 | R: 0.3360 | mAP@0.5: 0.2836 | mAP@0.5:0.95: 0.0887
# Epoch 29/40: 100% 439/439 [01:23<00:00,  5.25it/s, box=0.080, cls=0.138, obj=0.191, total=0.863]
# Epoch 29/40 | loss: 0.8627
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.55it/s]
#                    all       1001       3021      0.369      0.358      0.293      0.088
# 📊 Val | P: 0.3693 | R: 0.3583 | mAP@0.5: 0.2929 | mAP@0.5:0.95: 0.0880
# Epoch 30/40: 100% 439/439 [01:24<00:00,  5.17it/s, box=0.078, cls=0.143, obj=0.192, total=0.834]
# Epoch 30/40 | loss: 0.8338
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.88it/s]
#                    all       1001       3021      0.413      0.348        0.3     0.0952
# 📊 Val | P: 0.4128 | R: 0.3478 | mAP@0.5: 0.3001 | mAP@0.5:0.95: 0.0952
# Epoch 31/40: 100% 439/439 [01:24<00:00,  5.22it/s, box=0.079, cls=0.134, obj=0.174, total=0.759]
# Epoch 31/40 | loss: 0.7590
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.23it/s]
#                    all       1001       3021      0.417      0.355      0.314     0.0966
# 📊 Val | P: 0.4172 | R: 0.3547 | mAP@0.5: 0.3136 | mAP@0.5:0.95: 0.0966
# Epoch 32/40: 100% 439/439 [01:25<00:00,  5.13it/s, box=0.078, cls=0.137, obj=0.175, total=0.616]
# Epoch 32/40 | loss: 0.6156
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.67it/s]
#                    all       1001       3021      0.421      0.371      0.328      0.104
# 📊 Val | P: 0.4212 | R: 0.3709 | mAP@0.5: 0.3284 | mAP@0.5:0.95: 0.1044
# Epoch 33/40: 100% 439/439 [01:24<00:00,  5.19it/s, box=0.081, cls=0.142, obj=0.189, total=0.882]
# Epoch 33/40 | loss: 0.8824
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.09it/s]
#                    all       1001       3021      0.409      0.357      0.324      0.109
# 📊 Val | P: 0.4088 | R: 0.3571 | mAP@0.5: 0.3244 | mAP@0.5:0.95: 0.1088
# Epoch 34/40: 100% 439/439 [01:23<00:00,  5.23it/s, box=0.076, cls=0.125, obj=0.180, total=0.458]
# Epoch 34/40 | loss: 0.4582
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.59it/s]
#                    all       1001       3021      0.408      0.363      0.329       0.11
# 📊 Val | P: 0.4079 | R: 0.3629 | mAP@0.5: 0.3289 | mAP@0.5:0.95: 0.1102
# Epoch 35/40: 100% 439/439 [01:25<00:00,  5.16it/s, box=0.078, cls=0.134, obj=0.191, total=0.843]
# Epoch 35/40 | loss: 0.8435
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.39it/s]
#                    all       1001       3021      0.395      0.365      0.315      0.111
# 📊 Val | P: 0.3950 | R: 0.3652 | mAP@0.5: 0.3146 | mAP@0.5:0.95: 0.1106
# Epoch 36/40: 100% 439/439 [01:23<00:00,  5.23it/s, box=0.080, cls=0.129, obj=0.171, total=0.641]
# Epoch 36/40 | loss: 0.6409
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.56it/s]
#                    all       1001       3021      0.387      0.362      0.325      0.102
# 📊 Val | P: 0.3865 | R: 0.3623 | mAP@0.5: 0.3253 | mAP@0.5:0.95: 0.1023
# Epoch 37/40: 100% 439/439 [01:24<00:00,  5.21it/s, box=0.077, cls=0.134, obj=0.175, total=0.570]
# Epoch 37/40 | loss: 0.5699
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:12<00:00, 10.26it/s]
#                    all       1001       3021      0.407      0.374      0.339      0.119
# 📊 Val | P: 0.4072 | R: 0.3739 | mAP@0.5: 0.3393 | mAP@0.5:0.95: 0.1189
# Epoch 38/40: 100% 439/439 [01:25<00:00,  5.14it/s, box=0.078, cls=0.137, obj=0.196, total=0.870]
# Epoch 38/40 | loss: 0.8698
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 11.27it/s]
#                    all       1001       3021        0.4      0.369       0.34      0.117
# 📊 Val | P: 0.3998 | R: 0.3689 | mAP@0.5: 0.3397 | mAP@0.5:0.95: 0.1167
# Epoch 39/40: 100% 439/439 [01:24<00:00,  5.19it/s, box=0.079, cls=0.130, obj=0.183, total=0.833]
# Epoch 39/40 | loss: 0.8329
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.89it/s]
#                    all       1001       3021      0.435      0.356      0.339      0.115
# 📊 Val | P: 0.4348 | R: 0.3558 | mAP@0.5: 0.3387 | mAP@0.5:0.95: 0.1152
# Epoch 40/40: 100% 439/439 [01:25<00:00,  5.15it/s, box=0.078, cls=0.127, obj=0.187, total=0.606]
# Epoch 40/40 | loss: 0.6064
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 126/126 [00:11<00:00, 10.62it/s]
#                    all       1001       3021      0.426       0.36      0.339      0.116
# 📊 Val | P: 0.4257 | R: 0.3600 | mAP@0.5: 0.3389 | mAP@0.5:0.95: 0.1157
#
# ✅ Training complete
